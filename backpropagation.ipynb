# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'cgpa': [8,7,6,5],
    'resume_score': [8,9,10,12],
    'lpa': [4,5,6,7]
})

# %%
df
# Out:
#    cgpa  resume_score  lpa
# 0     8             8    4
# 1     7             9    5
# 2     6            10    6
# 3     5            12    7
